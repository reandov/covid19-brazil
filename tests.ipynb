# %%
import pandas as pd

# %%
cases = pd.read_csv("data/covid19-dataset-brasil-io_cleaned.csv")

# %%
cases[cases['is_last'] == True]
# Out:
#             date last_available_date  is_last        region state  \
# 348   2021-02-28          2021-02-28     True         Norte    AC
# 701   2021-02-28          2021-02-28     True         Norte    AM
# 1047  2021-02-28          2021-02-28     True         Norte    AP
# 1405  2021-02-28          2021-02-28     True      Nordeste    AL
# 1764  2021-02-28          2021-02-28     True  Centro-Oeste    DF
# 2125  2021-02-28          2021-02-28     True       Sudeste    ES
# 2475  2021-02-28          2021-02-28     True      Nordeste    CE
# 2835  2021-02-28          2021-02-28     True      Nordeste    BA
# 3189  2021-02-28          2021-02-28     True  Centro-Oeste    GO
# 3535  2021-02-28          2021-02-28     True      Nordeste    MA
# 3886  2021-02-27          2021-02-27     True  Centro-Oeste    MS
# 4233  2021-02-28          2021-02-28     True  Centro-Oeste    MT
# 4581  2021-02-28          2021-02-28     True         Norte    PA
# ...

# %%
cases[cases['is_last'] == True].new_cases.sum() + 542 + 330 + 273 + 590
# Out:
# 33961
